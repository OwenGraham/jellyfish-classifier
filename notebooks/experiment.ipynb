# %%
import torch
import torchvision

# %% [markdown]
# ### Check directory

# %%
import os
print(os.getcwd())  # Shows current working directory
# Out:
# c:\Users\OwenG\Documents\Machine_Learning\jellyfish\notebooks

# %%
import sys
import os

# Get the absolute path of the project root (adjust if necessary)
project_root = os.path.abspath("..")  # Moves one level up to the root

# Add it to sys.path if not already present
if project_root not in sys.path:
    sys.path.append(project_root)

# %% [markdown]
# ### Check GPU

# %%
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
print("cuDNN version:", torch.backends.cudnn.version())
print("Number of GPUs:", torch.cuda.device_count())
if torch.cuda.is_available():
    print("GPU Name:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# CUDA version: 12.4
# cuDNN version: 90100
# Number of GPUs: 1
# GPU Name: NVIDIA GeForce RTX 3050 6GB Laptop GPU

# %% [markdown]
# ### Test loss plotter

# %%
from utils.visualisations import plotloss
# Generate a list of 20 numbers
test_loss = [0.1, 0.08, 0.07, 0.06, 0.05, 0.045, 0.04, 0.035, 0.03, 0.025, 0.02, 0.018, 0.016, 0.014, 0.012, 0.01, 0.009, 0.008, 0.007, 0.006]

# Plot the test loss
plotloss(test_loss)

# %% [markdown]
# ### Test dataloader

# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt

from data.data_loader import get_data_loaders

_,testloader,_ = get_data_loaders()

dataiter = iter(testloader)
images, labels = next(dataiter)

torchvision.utils.make_grid(images)

plt.imshow(np.transpose(torchvision.utils.make_grid(images).numpy(), (1, 2, 0)))
plt.axis('off')
plt.show()
